# %%
using PyCall

# %%
# using Pkg; Pkg.add("Pandas")

# %%
using Pandas

# %%
df = Pandas.read_csv("../DataScience/data/temperatures.csv")
# Out:
#      Year  Month  Day  Brisbane  GoldCoast
# 0    2015      1    1      31.3       30.9
# 1    2015      1    2      30.5       30.1
# 2    2015      1    3      28.9       30.1
# 3    2015      1    4      30.2       30.1
# 4    2015      1    5      28.1       28.0
# ..    ...    ...  ...       ...        ...
# 772  2017      2   11      37.0       32.6
# 773  2017      2   12      37.6       33.0
# 774  2017      2   13      35.6       31.5
# 775  2017      2   14      30.3       29.9
# 776  2017      2   15      30.4       30.4
#
# [777 rows x 5 columns]

# %%
df
# Out:
#      Year  Month  Day  Brisbane  GoldCoast
# 0    2015      1    1      31.3       30.9
# 1    2015      1    2      30.5       30.1
# 2    2015      1    3      28.9       30.1
# 3    2015      1    4      30.2       30.1
# 4    2015      1    5      28.1       28.0
# ..    ...    ...  ...       ...        ...
# 772  2017      2   11      37.0       32.6
# 773  2017      2   12      37.6       33.0
# 774  2017      2   13      35.6       31.5
# 775  2017      2   14      30.3       29.9
# 776  2017      2   15      30.4       30.4
#
# [777 rows x 5 columns]

# %%
series = Series(["BMW","Tyota","Honda"])
# Out:
# 0      BMW
# 1    Tyota
# 2    Honda
# dtype: object

# %%
series
# Out:
# 0      BMW
# 1    Tyota
# 2    Honda
# dtype: object

# %%
typeof(series)
# Out:
# Series

# %%
colors = Series(["Red","Yellow","Green"])
# Out:
# 0       Red
# 1    Yellow
# 2     Green
# dtype: object

# %%
car_data = DataFrame(Dict("Car make" => series,"Color" =>colors))
# Out:
#   Car make   Color
# 0      BMW     Red
# 1    Tyota  Yellow
# 2    Honda   Green

# %%
car_data
# Out:
#   Car make   Color
# 0      BMW     Red
# 1    Tyota  Yellow
# 2    Honda   Green

# %%
car_data["Color"]
# Out:
# 0       Red
# 1    Yellow
# 2     Green
# Name: Color, dtype: object

# %%
car_data["Car make"]
# Out:
# 0      BMW
# 1    Tyota
# 2    Honda
# Name: Car make, dtype: object

# %%
iloc(car_data)[2:3,:]
# Out:
#   Car make   Color
# 1    Tyota  Yellow
# 2    Honda   Green

# %%
df1 = DataFrame(Dict(:slno => [1,2,3,4,5], :name =>["Sk","MK","LK","GK","Pk"], :age => [22,33,44,55,33]))
# Out:
#    age name  slno
# 0   22   Sk     1
# 1   33   MK     2
# 2   44   LK     3
# 3   55   GK     4
# 4   33   Pk     5

# %%
df2 = DataFrame(Dict(:slno => [1,2,3,4,5], :income => [2233,4456,7756,7876,4565]))
# Out:
#    income  slno
# 0    2233     1
# 1    4456     2
# 2    7756     3
# 3    7876     4
# 4    4565     5

# %%
mean(df1[:age])
# Out:
# 37.4

# %%
mean(groupby(df1,:age))
# Out:
#      slno
# age
# 22    1.0
# 33    3.5
# 44    3.0
# 55    4.0

# %%
query(df1, :(age > 40))
# Out:
#    age name  slno
# 2   44   LK     3
# 3   55   GK     4

# %%
Array(df1)
# Out:
# 5×3 Matrix{Any}:
#  22  "Sk"  1
#  33  "MK"  2
#  44  "LK"  3
#  55  "GK"  4
#  33  "Pk"  5

# %%
merge(df2,df1,left_on = "slno", right_index = true)
# Out:
#    slno  income  slno_x  age name  slno_y
# 0     1    2233       1   33   MK       2
# 1     2    4456       2   44   LK       3
# 2     3    7756       3   55   GK       4
# 3     4    7876       4   33   Pk       5

# %%
# not sure why fifth is not showing up

# %%
merge(df1,df2)
# Out:
#    age name  slno  income
# 0   22   Sk     1    2233
# 1   33   MK     2    4456
# 2   44   LK     3    7756
# 3   55   GK     4    7876
# 4   33   Pk     5    4565

# %%
# Interesting join work without key :-)

# %%
df2.write_csv("../DataScience/data/saving_data.csv")
# Out:
# type DataFrame has no field write_csv
#
# Stacktrace:
#  [1] getproperty(x::DataFrame, s::Symbol)
#    @ Pandas ~/.julia/packages/Pandas/rAPmB/src/Pandas.jl:479
#  [2] top-level scope
#    @ In[26]:1
#  [3] eval
#    @ ./boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
@pyimport pandas as pd

# %%
pydf = pd.read_csv("../DataScience/data/temperatures.csv")
# Out:
# PyObject      Year  Month  Day  Brisbane  GoldCoast
# 0    2015      1    1      31.3       30.9
# 1    2015      1    2      30.5       30.1
# 2    2015      1    3      28.9       30.1
# 3    2015      1    4      30.2       30.1
# 4    2015      1    5      28.1       28.0
# ..    ...    ...  ...       ...        ...
# 772  2017      2   11      37.0       32.6
# 773  2017      2   12      37.6       33.0
# 774  2017      2   13      35.6       31.5
# 775  2017      2   14      30.3       29.9
# 776  2017      2   15      30.4       30.4
#
# [777 rows x 5 columns]

# %%
pydf.to_csv("../DataScience/data/savingData.csv")

# %%
pydf.to_excel("../DataScience/data/excelSave.xls", index=false)

# %%
pydf["Year"]
# Out:
# PyObject 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 772    2017
# 773    2017
# 774    2017
# 775    2017
# 776    2017
# Name: Year, Length: 777, dtype: int64

# %%
pyex = pd.read_excel("../DataScience/data/excelSave.xls")
# Out:
# PyObject      Year  Month  Day  Brisbane  GoldCoast
# 0    2015      1    1      31.3       30.9
# 1    2015      1    2      30.5       30.1
# 2    2015      1    3      28.9       30.1
# 3    2015      1    4      30.2       30.1
# 4    2015      1    5      28.1       28.0
# ..    ...    ...  ...       ...        ...
# 772  2017      2   11      37.0       32.6
# 773  2017      2   12      37.6       33.0
# 774  2017      2   13      35.6       31.5
# 775  2017      2   14      30.3       29.9
# 776  2017      2   15      30.4       30.4
#
# [777 rows x 5 columns]

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
# Out:
# PyObject      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# ...

# %%
s1 = pd.Series([1,2,3,4])
# Out:
# PyObject 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
typeof(s1)
# Out:
# PyObject

# %%
[x for x in s1]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  3
#  4

# %%
car_sales = pd.read_csv("./data/car-sales.csv")
# Out:
# PyObject      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
car_sales.dtypes
# Out:
# PyObject Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# PyObject Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
# Out:
# PyObject Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns
# Out:
# PyObject Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# PyObject RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
# PyObject        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.mean()
# Out:
# PyObject Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# PyObject Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
length(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
# PyObject      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## View and select data

# %%
car_sales.head()
# Out:
# PyObject      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
# PyObject      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
# PyObject      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## .loc and iloc

# %%
animals = pd.Series(["cat","bird","dog","panda","sanke"], index = [0,3,9,8,4])
# Out:
# PyObject 0      cat
# 3     bird
# 9      dog
# 8    panda
# 4    sanke
# dtype: object

# %%
animals.loc[0]
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /home/sandhya/.julia/packages/PyCall/BD546/src/PyCall.jl:775 =# @pysym(:PyObject_GetItem), PyPtr, (PyPtr, PyPtr), o, PyObject(k)))))) <class 'KeyError'>
# KeyError(-1)
#   File "/home/sandhya/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1767, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/home/sandhya/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1964, in _getitem_axis
#     return self._get_label(key, axis=axis)
#   File "/home/sandhya/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 620, in _get_label
#     return self.obj._xs(label, axis=axis)
#   File "/home/sandhya/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 3537, in xs
#     loc = self.index.get_loc(key)
#   File "/home/sandhya/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2648, in get_loc
# ...

# %%
animals.iloc[3]
# Out:
# "dog"

# %%
car_sales.loc[3]
# Out:
# PyObject Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
# When using index in Series, loc is not working as expected, if not, it is working fine
animals1 = pd.Series(["cat","bird","dog","panda","sanke"])
# Out:
# PyObject 0      cat
# 1     bird
# 2      dog
# 3    panda
# 4    sanke
# dtype: object

# %%
animals1.loc[3]
# Out:
# "dog"

# %%
car_sales.loc[3]
# Out:
# PyObject Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
# iloc refers position where loc refers to index
car_sales.iloc[4]
# Out:
# PyObject Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales
# Out:
# PyObject      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# expectation was to get three records but colon is now resolving
animals.iloc[:3]
# Out:
# "dog"

# %%
car_sales.loc[:3]
# Out:
# PyObject Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
ar = DataFrame(car_sales)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
typeof(ar)
# Out:
# DataFrame

# %%
ar[5:end]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00
